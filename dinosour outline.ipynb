# %%
import cv2
import matplotlib.pyplot as plt

# %%
img1=cv2.imread('download (1).png')
plt.imshow(img1)
plt.show()

# %%
gaussian = cv2.GaussianBlur(img1,(3,3),0)
edge = cv2.Canny(gaussian,200,300)
plt.imshow(edge)
plt.show()
